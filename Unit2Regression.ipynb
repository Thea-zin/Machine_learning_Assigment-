# %% [markdown]
# <a href="https://colab.research.google.com/github/Thea-zin/Machine_learning_Assigment-/blob/main/Unit2Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ScikitLearn

# %%
# data prepprocessing
import sklearn #machine learning
import numpy as np #computions
import pandas as pd # Data management

# %%
#1.load the dataset
#2.Dimensions of data set
#3.Check the variable (Numerical/ categorical)
#4.Missing values
#5.Find out the percentage of of missing values
#6.Replace
#7.fillup the missing values 
#8.Create the rows and add it with the original dataset
#9.choose the exact rows from the dataset
#10.Rename the columns 
#11.Find the min,max,sum,count
#12.Delete the rows and comlumns
#13.Unique value in the dataset.

# %%
#1.load the dataset
# data prepprocessing
import sklearn #machine learning
import numpy as np #computions
import pandas as pd # Data management
datasets = pd.read_csv("https://raw.githubusercontent.com/datasets/covid-19/main/data/key-countries-pivoted.csv")
datasets.head(5)
# Out:
#          Date  China  US  United_Kingdom  Italy  France  Germany  Spain  Iran
# 0  2020-01-22    548   1               0      0       0        0      0     0
# 1  2020-01-23    643   1               0      0       0        0      0     0
# 2  2020-01-24    920   2               0      0       2        0      0     0
# 3  2020-01-25   1406   2               0      0       3        0      0     0
# 4  2020-01-26   2075   5               0      0       3        0      0     0

# %%
#2. Know the dimensions 
datasets.shape
# Out:
# (816, 9)

# %%
datasets.describe()
# Out:
#               China            US  United_Kingdom         Italy        France  \
# count  8.160000e+02  8.160000e+02    8.160000e+02  8.160000e+02  8.160000e+02
# mean   1.696816e+05  2.814112e+07    5.363346e+06  3.571904e+06  5.623503e+06
# std    2.754920e+05  2.432460e+07    6.020675e+06  3.851434e+06  6.806034e+06
# min    5.480000e+02  1.000000e+00    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    9.318025e+04  5.247606e+06    3.164315e+05  2.521045e+05  2.481825e+05
# 50%    1.091465e+05  2.902645e+07    4.216773e+06  3.011124e+06  3.907140e+06
# 75%    1.194312e+05  4.292658e+07    7.644779e+06  4.654576e+06  7.076648e+06
# max    1.760211e+06  8.062512e+07    2.191696e+07  1.565984e+07  2.787427e+07
#
#             Germany         Spain          Iran
# count  8.160000e+02  8.160000e+02  8.160000e+02
# mean   3.685456e+06  3.375564e+06  2.667263e+06
# std    4.875119e+06  3.257851e+06  2.529457e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00
# ...

# %%
#3 check the variable (numerical/ categorical)'
numerical_variable = datasets.columns[datasets.dtypes!='object']
datasets[numerical_variable].head(10)

categorical_variable = datasets.columns[datasets.dtypes!='object']
datasets[categorical_variable].head(10)
# Out:
#    China  US  United_Kingdom  Italy  France  Germany  Spain  Iran
# 0    548   1               0      0       0        0      0     0
# 1    643   1               0      0       0        0      0     0
# 2    920   2               0      0       2        0      0     0
# 3   1406   2               0      0       3        0      0     0
# 4   2075   5               0      0       3        0      0     0
# 5   2877   5               0      0       3        1      0     0
# 6   5509   5               0      0       4        4      0     0
# 7   6087   6               0      0       5        4      0     0
# 8   8141   6               0      0       5        4      0     0
# 9   9802   8               2      2       5        5      0     0

# %%
#4 Missing value 
datasets.isnull().head(5)
# Out:
#     Date  China     US  United_Kingdom  Italy  France  Germany  Spain   Iran
# 0  False  False  False           False  False   False    False  False  False
# 1  False  False  False           False  False   False    False  False  False
# 2  False  False  False           False  False   False    False  False  False
# 3  False  False  False           False  False   False    False  False  False
# 4  False  False  False           False  False   False    False  False  False

# %%
#5 fid out the percentage of missing value 
len(datasets)
# Out:
# 816

# %%
datasets.isnull().sum()/len(datasets)
datasets[numerical_variable].isnull().sum()
datasets[numerical_variable].isnull().sum()/len(datasets)
# Out:
# China             0.0
# US                0.0
# United_Kingdom    0.0
# Italy             0.0
# France            0.0
# Germany           0.0
# Spain             0.0
# Iran              0.0
# dtype: float64

# %%
#6 replace
datasets.fillna('Missing ')
# Out:
#            Date    China        US  United_Kingdom     Italy    France  \
# 0    2020-01-22      548         1               0         0         0
# 1    2020-01-23      643         1               0         0         0
# 2    2020-01-24      920         2               0         0         2
# 3    2020-01-25     1406         2               0         0         3
# 4    2020-01-26     2075         5               0         0         3
# ..          ...      ...       ...             ...       ...       ...
# 811  2022-04-12  1655477  80477797        21846115  15404809  27353225
# 812  2022-04-13  1681437  80518989        21883579  15467395  27499728
# 813  2022-04-14  1705231  80573532        21916961  15533012  27637292
# 814  2022-04-15  1759128  80612681        21916961  15595302  27762686
# 815  2022-04-16  1760211  80625120        21916961  15659835  27874269
#
#       Germany     Spain     Iran
# 0           0         0        0
# 1           0         0        0
# ...

# %%
datasets['Italy'].replace(0,1)
datasets.replace(0,'KIT')
datasets['Italy'].replace([0,1],['KIT',0]).head(5)
# Out:
# 0    KIT
# 1    KIT
# 2    KIT
# 3    KIT
# 4    KIT
# Name: Italy, dtype: object

# %%
#7 create the rows and add it with the original data
#value of variable , instruction about the variable 
row_insert=pd.Series(['2020-01-21','5','50','0','1','2','3','4','5'],index=['Data',['China'],['US'],['United_Kingdom'],['Italy'],['France'],['Germany'],['Spain'],['Iran']])
datasets.head(5)
# Out:
#                   Date  China  US  United_Kingdom  Italy  France  Germany  \
# Date
# 2020-01-22  2020-01-22    548   1               0      0       0        0
# 2020-01-23  2020-01-23    643   1               0      0       0        0
# 2020-01-24  2020-01-24    920   2               0      0       2        0
# 2020-01-25  2020-01-25   1406   2               0      0       3        0
# 2020-01-26  2020-01-26   2075   5               0      0       3        0
#
#             Spain  Iran
# Date
# 2020-01-22      0     0
# 2020-01-23      0     0
# 2020-01-24      0     0
# 2020-01-25      0     0
# 2020-01-26      0     0

# %%
# 8 call the row
#datasetname.iloc[]-we can call the specific row based on the index
datasets.iloc[0]
datasets.iloc[1:5]
datasets.iloc[1:6]
datasets.iloc[:7]

# %%
#9 loc to call the specific values,
#index
datasets=datasets.set_index(datasets['Date'])
datasets.loc['2020-01-22']
# Out:
# Date              2020-01-22
# China                    548
# US                         1
# United_Kingdom             0
# Italy                      0
# France                     0
# Germany                    0
# Spain                      0
# Iran                       0
# Name: 2020-01-22, dtype: object

# %%
#10rename
datasets.rename(columns={'US':'Cambodia'}).head(5)
# Out:
#                   Date  China  Cambodia  United_Kingdom  Italy  France  \
# Date
# 2020-01-22  2020-01-22    548         1               0      0       0
# 2020-01-23  2020-01-23    643         1               0      0       0
# 2020-01-24  2020-01-24    920         2               0      0       2
# 2020-01-25  2020-01-25   1406         2               0      0       3
# 2020-01-26  2020-01-26   2075         5               0      0       3
#
#             Germany  Spain  Iran
# Date
# 2020-01-22        0      0     0
# 2020-01-23        0      0     0
# 2020-01-24        0      0     0
# 2020-01-25        0      0     0
# 2020-01-26        0      0     0

# %%
#max dataset
print("max: ",datasets['China'].max())
#dataset min
print(print("min: ",datasets['China'].min()))
#dataset sum
print("sum: ",datasets['China'].sum())
#dataset count
print("count: ",datasets['China'].count())
# Out:
# max:  1760211
# min:  548
# None
# sum:  138460190
# count:  816

# %%
#11 delete dataset col
datasets.drop("China",axis=1).head(5)
# Out:
#                   Date  US  United_Kingdom  Italy  France  Germany  Spain  \
# Date
# 2020-01-22  2020-01-22   1               0      0       0        0      0
# 2020-01-23  2020-01-23   1               0      0       0        0      0
# 2020-01-24  2020-01-24   2               0      0       2        0      0
# 2020-01-25  2020-01-25   2               0      0       3        0      0
# 2020-01-26  2020-01-26   5               0      0       3        0      0
#
#             Iran
# Date
# 2020-01-22     0
# 2020-01-23     0
# 2020-01-24     0
# 2020-01-25     0
# 2020-01-26     0

# %%
#12 delete datasets row

datasets.drop([1], axis =0).head(5)
# Out:
#          Date  China  US  United_Kingdom  Italy  France  Germany  Spain  Iran
# 0  2020-01-22    548   1               0      0       0        0      0     0
# 2  2020-01-24    920   2               0      0       2        0      0     0
# 3  2020-01-25   1406   2               0      0       3        0      0     0
# 4  2020-01-26   2075   5               0      0       3        0      0     0
# 5  2020-01-27   2877   5               0      0       3        1      0     0

# %%
#13 find unique value 
datasets['Date'].unique()
# Out:
# array(['2020-01-22', '2020-01-23', '2020-01-24', '2020-01-25',
#        '2020-01-26', '2020-01-27', '2020-01-28', '2020-01-29',
#        '2020-01-30', '2020-01-31', '2020-02-01', '2020-02-02',
#        '2020-02-03', '2020-02-04', '2020-02-05', '2020-02-06',
#        '2020-02-07', '2020-02-08', '2020-02-09', '2020-02-10',
#        '2020-02-11', '2020-02-12', '2020-02-13', '2020-02-14',
#        '2020-02-15', '2020-02-16', '2020-02-17', '2020-02-18',
#        '2020-02-19', '2020-02-20', '2020-02-21', '2020-02-22',
#        '2020-02-23', '2020-02-24', '2020-02-25', '2020-02-26',
#        '2020-02-27', '2020-02-28', '2020-02-29', '2020-03-01',
#        '2020-03-02', '2020-03-03', '2020-03-04', '2020-03-05',
#        '2020-03-06', '2020-03-07', '2020-03-08', '2020-03-09',
#        '2020-03-10', '2020-03-11', '2020-03-12', '2020-03-13',
#        '2020-03-14', '2020-03-15', '2020-03-16', '2020-03-17',
#        '2020-03-18', '2020-03-19', '2020-03-20', '2020-03-21',
# ...
